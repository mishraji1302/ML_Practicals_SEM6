# %% [markdown]
# <a href="https://colab.research.google.com/github/mishraji1302/ML_Practicals_SEM6/blob/main/ML_exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.preprocessing import MinMaxScaler

# Load dataset
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['species'] = iris.target

# Data Cleaning (no missing values here, but checking)
print(df.isnull().sum())

# Normalization
scaler = MinMaxScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df.iloc[:, :-1]),
                         columns=df.columns[:-1])

# Scatter Plot
plt.scatter(df_scaled['sepal length (cm)'], df_scaled['petal length (cm)'])
plt.title("Scatter Plot")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.show()

# Histogram
df_scaled.hist()
plt.show()

# Box Plot
df_scaled.boxplot()
plt.show()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64
